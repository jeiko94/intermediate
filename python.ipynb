# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\yeisson.villamil\OneDrive - MVM Ingenieria de Software\Escritorio\Carpetas\Data engineer\Data\sales.csv')

df.head(1)
# Out:
#   SalesOrderNumber  SalesOrderLineNumber   OrderDate CustomerName  \
# 0          SO43701                     1  2019-07-01  Christy Zhu
#
#                     EmailAddress                     Item  Quantity  \
# 0  christy12@adventure-works.com  Mountain-100 Silver, 44         1
#
#    UnitPrice  TaxAmount
# 0    3399.99   271.9992

# %%
df_selected = df[['CustomerName','EmailAddress']]

df_selected.head(1)
# Out:
#   CustomerName                   EmailAddress
# 0  Christy Zhu  christy12@adventure-works.com

# %%
filter = df[df['OrderDate'] > '2019-07-20']

filter.head(5)
# Out:
#     SalesOrderNumber  SalesOrderLineNumber   OrderDate     CustomerName  \
# 181          SO43957                     1  2019-07-21      Amanda Wood
# 182          SO43953                     1  2019-07-21   Colleen Chavez
# 183          SO43960                     1  2019-07-21   Christine Yuan
# 184          SO43959                     1  2019-07-21  Wendy Dominguez
# 185          SO43956                     1  2019-07-21     Bethany Yuan
#
#                        EmailAddress                     Item  Quantity  \
# 181    amanda23@adventure-works.com         Road-150 Red, 52         1
# 182   colleen38@adventure-works.com       Road-650 Black, 52         1
# 183  christine4@adventure-works.com   Mountain-100 Black, 42         1
# 184     wendy12@adventure-works.com   Mountain-100 Black, 38         1
# 185   bethany10@adventure-works.com  Mountain-100 Silver, 38         1
#
#      UnitPrice  TaxAmount
# 181  3578.2700   286.2616
# 182   699.0982    55.9279
# ...

# %%
df['Total'] = df['Quantity'] * df['UnitPrice']
df['TotalConImpuesto'] = df['Total'] + df['TaxAmount']

df[['CustomerName', 'Total', 'TotalConImpuesto']].head(5)
# Out:
#      CustomerName      Total  TotalConImpuesto
# 0     Christy Zhu  3399.9900         3671.9892
# 1      Julio Ruiz  3374.9900         3644.9892
# 2       Curtis Lu  3399.9900         3671.9892
# 3    Ruben Prasad   699.0982          755.0261
# 4  Albert Alvarez  3578.2700         3864.5316

# %%
df_renamed = df.rename(columns={
    'CustomerName': 'Nombre del cliente',
    'EmailAddress': 'Correo electronico',
    'OrderDate': 'Fecha de orden',
    'Total': 'Total sin impuesto',
    'TotalConImpuesto': 'Total con impuesto'
})

df_renamed.head(5)
# Out:
#   SalesOrderNumber  SalesOrderLineNumber Fecha de orden Nombre del cliente  \
# 0          SO43701                     1     2019-07-01        Christy Zhu
# 1          SO43704                     1     2019-07-01         Julio Ruiz
# 2          SO43705                     1     2019-07-01          Curtis Lu
# 3          SO43700                     1     2019-07-01       Ruben Prasad
# 4          SO43703                     1     2019-07-01     Albert Alvarez
#
#               Correo electronico                     Item  Quantity  \
# 0  christy12@adventure-works.com  Mountain-100 Silver, 44         1
# 1     julio1@adventure-works.com   Mountain-100 Black, 48         1
# 2    curtis9@adventure-works.com  Mountain-100 Silver, 38         1
# 3    ruben10@adventure-works.com       Road-650 Black, 62         1
# 4    albert7@adventure-works.com         Road-150 Red, 62         1
#
#    UnitPrice  TaxAmount  Total sin impuesto  Total con impuesto
# ...
